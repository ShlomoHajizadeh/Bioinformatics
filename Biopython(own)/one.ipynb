# %%
# %pip install biopython
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import Bio
print(Bio.__version__)
# Out:
# 1.77

# %%
from Bio.Seq import Seq
my_seq = Seq("AGTACACTGGT")
my_seq
Seq('AGTACACTGGT')
print(my_seq)
# Out:
# AGTACACTGGT

# %%
my_seq
Seq('AGTACACTGGT')
my_seq.complement()
Seq('TCATGTGACCA')
my_seq.reverse_complement()
Seq('ACCAGTGTACT')
# Out:
# Seq('ACCAGTGTACT')

# %%
from Bio import SeqIO

file_path = r"/Users/shlomohajizadeh/Documents/GitHub/Bioinformatics/Biopython(own)/data/ls_orchid.fasta"

for seq_record in SeqIO.parse(file_path, "fasta"):
    print("Sequence id",seq_record.id)
    print("Sequence",repr(seq_record.seq))
    print("Sequence length",len(seq_record))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 5
#       1 from Bio import SeqIO
#       3 file_path = r"/Users/shlomohajizadeh/Documents/GitHub/Bioinformatics/Biopython(own)/data/ls_orchid.fasta"
# ----> 5 for seq_record in SeqIO.parse(file_path, "fasta"):
#       6     print("Sequence id",seq_record.id)
#       7     print("Sequence",repr(seq_record.seq))
#
# File /opt/anaconda3/lib/python3.12/site-packages/Bio/SeqIO/__init__.py:627, in parse(handle, format, alphabet)
#     625 if iterator_generator:
#     626     if alphabet is None:
# --> 627         i = iterator_generator(handle)
#     628     else:
#     629         try:
#
# File /opt/anaconda3/lib/python3.12/site-packages/Bio/SeqIO/FastaIO.py:181, in FastaIterator.__init__(self, source, alphabet, title2ids)
#     141 """Iterate over Fasta records as SeqRecord objects.
#     142
#     143 Arguments:
# ...
